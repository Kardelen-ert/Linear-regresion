# %%
import pandas as pd
df=pd.read_csv("Advertising Budget and Sales.csv")
df=df.iloc[:,1:len(df)]
df.head()
# Out:
#    TV Ad Budget ($)  Radio Ad Budget ($)  Newspaper Ad Budget ($)  Sales ($)
# 0             230.1                 37.8                     69.2       22.1
# 1              44.5                 39.3                     45.1       10.4
# 2              17.2                 45.9                     69.3        9.3
# 3             151.5                 41.3                     58.5       18.5
# 4             180.8                 10.8                     58.4       12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TV Ad Budget ($)         200 non-null    float64
#  1   Radio Ad Budget ($)      200 non-null    float64
#  2   Newspaper Ad Budget ($)  200 non-null    float64
#  3   Sales ($)                200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
import seaborn as  sns 
sns.jointplot(x="TV Ad Budget ($)", y="Sales ($)", data=df, kind="reg")

# %%
from sklearn.linear_model import LinearRegression

# %%
X=df[["TV Ad Budget ($)"]]
X.head()
# Out:
#    TV Ad Budget ($)
# 0             230.1
# 1              44.5
# 2              17.2
# 3             151.5
# 4             180.8

# %%
y=df[["Sales ($)"]]
y.head()
# Out:
#    Sales ($)
# 0       22.1
# 1       10.4
# 2        9.3
# 3       18.5
# 4       12.9

# %%
reg=LinearRegression()
model=reg.fit(x,y)

# %%
model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X, y)
str(model)
dir(model)

# %%
model.coef_
model.intercept_
model.score(X,y)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 
g = sns.regplot(x=df["TV Ad Budget ($)"], y=df["Sales ($)"], ci=None, scatter_kws={'color':'r', 's':9})
g.set_title="Model Denklemi=7.05+TV Ad Budget*0.045 "
g.set_ylabel("Satış Sayısı")
g.set_xlabel("TV")
plt.xlim(-10,310)
plt.ylim(bottom=0)
# Out:
# (0.0, 28.27)

# %%
model.intercept_+model.coef_*165

# %%
model.predict([[165]])

# %%
yeni_veri=[[5],[10],[15]]

# %%
yeni_veri = [[5], [10], [15]]  
tahminler = model.predict(yeni_veri)
print("Tahmin edilen satış sayıları:", tahminler)
# Out:
# C:\Users\karde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
